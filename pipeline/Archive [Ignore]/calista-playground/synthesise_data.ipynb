# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta
import numpy as np
import random
import json
import math
from typing import List, Tuple

# %%
def get_service_poll_date(file_path):
    all_info = file_path.split("_")
    service = all_info[2]
    poll_rate = all_info[3]
    date_concerned = datetime.strptime(all_info[4].split(".")[0], '%d-%m-%Y')

    print("Service is:",service)
    print("Poll rate is:",poll_rate)
    print("Date is:",date_concerned)
    print()

    return [service, poll_rate, date_concerned]

def filter_df_for_date(df, date_concerned, svc_start_time, svc_end_time):
    start_time = datetime.strptime(svc_start_time,'%H%M').time()
    end_time = datetime.strptime(svc_end_time,'%H%M').time()


    sched_start = datetime.combine(date_concerned, start_time)
    if end_time < start_time: #end time is past midnight
        sched_end = datetime.combine(date_concerned + timedelta(days=1), end_time)
    else:
        sched_end = datetime.combine(date_concerned, end_time)

    print("schedule starts at", sched_start)
    print("schedule ends at", sched_end)

    filtered_df = df[df["vehicleTimestamp"] > sched_start]
    filtered_df = df[df["vehicleTimestamp"] < sched_end]

    return filtered_df

def clean_data(orig_df):
    cleaned_df = orig_df.copy() 
    cleaned_df["vehicleTimestamp"] = pd.to_datetime(cleaned_df["vehicleTimestamp"], unit="s")
    cleaned_df.drop(["pippenId", "pippenCreatedAt", "pippenPollingRate", "tripStartTime", "tripStartDate", "tripRouteId"] , axis=1, inplace = True)
    cleaned_df["tripDirectionId"] = np.where((cleaned_df["vehicleLabel"] == "FX2 To Portland") | (cleaned_df["vehicleLabel"] == "FX2 To NW 5th & Hoyt") | (cleaned_df["vehicleLabel"] == "FX2 To NW Irving & 5th"), 1, 0)
    cleaned_df.dropna(subset=["vehicleStopID"], inplace=True)
    cleaned_df["vehicleStopID"] = cleaned_df["vehicleStopID"].astype(int)

    cleaned_df.drop_duplicates(inplace=True)
    cleaned_df.sort_values(by=['tripId', "vehicleStopSequence"], inplace=True)
    


        # if row["vehicleStopSequence"] >2:
        #     cleaned_df.drop(index, inplace = True)

    # for index, row in cleaned_df.groupby("tripId").head(1).sort_values("tripId").iterrows():
    #     print(row["vehicleStopSequence"])


    return cleaned_df

# %%
data = "gtfs_data_2_15s_07-10-2023.csv"
date_concerned = get_service_poll_date(data)[2]
df = pd.read_csv(data)
df = clean_data(df)
df = filter_df_for_date(df, date_concerned, "0500", "0100")
df = df[df["tripDirectionId"] ==0]
df.sort_values(["tripId","vehicleTimestamp"])
# Out:
# trip number: 49
# trip id: 12782067
# first stop sequence: 4
#
# trip number: 86
# trip id: 12782280
# first stop sequence: 41
#
# trip number: 87
# trip id: 12782281
# first stop sequence: 24
#
# trip number: 88
# trip id: 12782282
# first stop sequence: 13
#
# trip number: 183
# trip id: 12782738
# first stop sequence: 39
#
# trip number: 184
# trip id: 12782739
# first stop sequence: 24
#
# trip number: 185
# trip id: 12782740
# first stop sequence: 8
#
# schedule starts at 2023-10-07 05:00:00
# schedule ends at 2023-10-08 01:00:00
#          tripId  tripDirectionId    vehicleTimestamp          vehicleLabel  \
# 2123   12782018                0 2023-10-07 12:32:34        FX2 To Gresham
# 2131   12782018                0 2023-10-07 12:33:04        FX2 To Gresham
# 2139   12782018                0 2023-10-07 12:33:31        FX2 To Gresham
# 2159   12782018                0 2023-10-07 12:34:37        FX2 To Gresham
# 2167   12782018                0 2023-10-07 12:35:10        FX2 To Gresham
# ...         ...              ...                 ...                   ...
# 56956  12782288                0 2023-10-07 09:34:30  FX2 To Cleveland Ave
# 56958  12782288                0 2023-10-07 09:34:57  FX2 To Cleveland Ave
# 56960  12782288                0 2023-10-07 09:35:27  FX2 To Cleveland Ave
# 1312   12782288                0 2023-10-07 09:35:57  FX2 To Cleveland Ave
# 1314   12782288                0 2023-10-07 09:36:27  FX2 To Cleveland Ave
#
#        vehicleID  vehicleLat  vehicleLong  vehicleBearing  \
# 2123        4525   45.527695  -122.675570             178
# 2131        4525   45.527695  -122.675570             178
# 2139        4525   45.527550  -122.675560             178
# 2159        4525   45.527550  -122.675560             178
# 2167        4525   45.524770  -122.675460             178
# ...          ...         ...          ...             ...
# 56956       4526   45.502920  -122.427734              89
# 56958       4526   45.502956  -122.425460              88
# 56960       4526   45.503010  -122.421710              88
# 1312        4526   45.503036  -122.419170              88
# 1314        4526   45.503040  -122.418800              88
#
#        vehicleStopSequence  vehicleStopID vehicleCurrentStatus
# 2123                     1           9302           STOPPED_AT
# 2131                     1           9302           STOPPED_AT
# 2139                     2           9301        IN_TRANSIT_TO
# 2159                     2           9301        IN_TRANSIT_TO
# 2167                     2           9301           STOPPED_AT
# ...                    ...            ...                  ...
# 56956                   41           8199        IN_TRANSIT_TO
# 56958                   42          14230        IN_TRANSIT_TO
# 56960                   42          14230        IN_TRANSIT_TO
# 1312                    42          14230        IN_TRANSIT_TO
# 1314                    42          14230           STOPPED_AT
#
# [9638 rows x 11 columns]

# %%
df.groupby("tripId").head(1).sort_values("tripId")["vehicleStopSequence"].unique()
# Out:
# array([ 0,  1, 24, 13])

# %%
df[df["tripId"]==12782025]
# Out:
#          tripId  tripDirectionId    vehicleTimestamp          vehicleLabel  \
# 5333   12782025                0 2023-10-07 14:25:35        FX2 To Gresham
# 5355   12782025                0 2023-10-07 14:26:05        FX2 To Gresham
# 5377   12782025                0 2023-10-07 14:26:36        FX2 To Gresham
# 5399   12782025                0 2023-10-07 14:27:05        FX2 To Gresham
# 5421   12782025                0 2023-10-07 14:27:39        FX2 To Gresham
# ...         ...              ...                 ...                   ...
# 15006  12782025                0 2023-10-07 15:33:15  FX2 To Cleveland Ave
# 15032  12782025                0 2023-10-07 15:33:45  FX2 To Cleveland Ave
# 15058  12782025                0 2023-10-07 15:34:15  FX2 To Cleveland Ave
# 15084  12782025                0 2023-10-07 15:34:48  FX2 To Cleveland Ave
# 15097  12782025                0 2023-10-07 15:35:03  FX2 To Cleveland Ave
#
#        vehicleID  vehicleLat  vehicleLong  vehicleBearing  \
# 5333        4524   45.527695  -122.675570             178
# 5355        4524   45.527695  -122.675570             178
# 5377        4524   45.527695  -122.675570             178
# 5399        4524   45.527695  -122.675570             178
# 5421        4524   45.527695  -122.675570             178
# ...          ...         ...          ...             ...
# 15006       4524   45.502934  -122.426346              89
# 15032       4524   45.502990  -122.422930              88
# 15058       4524   45.503020  -122.420470              89
# 15084       4524   45.503040  -122.418830              88
# 15097       4524   45.503048  -122.418304              88
#
#        vehicleStopSequence  vehicleStopID vehicleCurrentStatus
# 5333                     1         9302.0           STOPPED_AT
# 5355                     1         9302.0           STOPPED_AT
# 5377                     1         9302.0           STOPPED_AT
# 5399                     1         9302.0           STOPPED_AT
# 5421                     1         9302.0           STOPPED_AT
# ...                    ...            ...                  ...
# 15006                   42        14230.0        IN_TRANSIT_TO
# 15032                   42        14230.0        IN_TRANSIT_TO
# 15058                   42        14230.0        IN_TRANSIT_TO
# 15084                   42        14230.0           STOPPED_AT
# 15097                    0            NaN                  NaN
#
# [148 rows x 11 columns]

# %%
data2 = "gtfs_data_2_15s_12-10-2023.csv"
date_concerned = get_service_poll_date(data2)[2]
df2 = pd.read_csv(data2)
df2 = clean_data(df2)
df2 = filter_df_for_date(df2, date_concerned, "0500", "0100")
df2 = df2[df2["tripDirectionId"] ==0]
# df2.sort_values(["tripId","vehicleTimestamp"], inplace=True)
df2.sort_values(["tripId","vehicleStopSequence"], inplace=True)
df2.reset_index(inplace=True)

print("number of trips:",df2["tripId"].nunique())
print()
for index, row in df2.groupby("tripId").head(1).sort_values("vehicleTimestamp").reset_index().iterrows():
    if row["vehicleStopSequence"] == 1:
        print("trip number:",index)
        print("timestamp:", row["vehicleTimestamp"])
        print("trip id:",row["tripId"])
        print("first stop sequence:", row["vehicleStopSequence"])
        print()
# Out:
# schedule starts at 2023-10-12 05:00:00
# schedule ends at 2023-10-13 01:00:00
# number of trips: 72
#
# trip number: 0
# timestamp: 2023-10-12 06:59:38
# trip id: 12845725
# first stop sequence: 1
#
# trip number: 3
# timestamp: 2023-10-12 07:07:04
# trip id: 12845726
# first stop sequence: 1
#
# trip number: 4
# timestamp: 2023-10-12 07:28:54
# trip id: 12845727
# first stop sequence: 1
#
# trip number: 5
# timestamp: 2023-10-12 07:54:51
# trip id: 12845728
# first stop sequence: 1
#
# trip number: 6
# timestamp: 2023-10-12 08:09:52
# trip id: 12845729
# first stop sequence: 1
#
# trip number: 7
# timestamp: 2023-10-12 08:29:52
# trip id: 12845730
# first stop sequence: 1
#
# trip number: 8
# timestamp: 2023-10-12 12:01:05
# trip id: 12845636
# first stop sequence: 1
#
# trip number: 9
# timestamp: 2023-10-12 12:20:26
# trip id: 12845637
# first stop sequence: 1
#
# trip number: 10
# timestamp: 2023-10-12 12:44:43
# trip id: 12845638
# first stop sequence: 1
#
# trip number: 11
# timestamp: 2023-10-12 13:06:00
# trip id: 12845639
# first stop sequence: 1
#
# trip number: 12
# timestamp: 2023-10-12 13:20:51
# trip id: 12845640
# first stop sequence: 1
#
# trip number: 13
# timestamp: 2023-10-12 13:36:07
# trip id: 12845641
# first stop sequence: 1
#
# trip number: 14
# timestamp: 2023-10-12 13:52:57
# trip id: 12845642
# first stop sequence: 1
#
# trip number: 15
# timestamp: 2023-10-12 14:12:32
# trip id: 12845643
# first stop sequence: 1
#
# trip number: 16
# timestamp: 2023-10-12 14:13:23
# trip id: 12845644
# first stop sequence: 1
#
# trip number: 17
# timestamp: 2023-10-12 14:28:18
# trip id: 12845645
# first stop sequence: 1
#
# trip number: 18
# timestamp: 2023-10-12 14:36:52
# trip id: 12845646
# first stop sequence: 1
#
# trip number: 19
# timestamp: 2023-10-12 14:52:54
# trip id: 12845647
# first stop sequence: 1
#
# trip number: 20
# timestamp: 2023-10-12 15:01:40
# trip id: 12845648
# first stop sequence: 1
#
# trip number: 21
# timestamp: 2023-10-12 15:15:12
# trip id: 12845649
# first stop sequence: 1
#
# trip number: 22
# timestamp: 2023-10-12 15:24:58
# trip id: 12845650
# first stop sequence: 1
#
# trip number: 23
# timestamp: 2023-10-12 15:39:08
# trip id: 12845651
# first stop sequence: 1
#
# trip number: 24
# timestamp: 2023-10-12 15:50:57
# trip id: 12845652
# first stop sequence: 1
#
# trip number: 25
# timestamp: 2023-10-12 16:00:37
# trip id: 12845653
# first stop sequence: 1
#
# trip number: 26
# timestamp: 2023-10-12 16:16:39
# trip id: 12845654
# first stop sequence: 1
#
# trip number: 27
# timestamp: 2023-10-12 16:28:07
# trip id: 12845655
# first stop sequence: 1
#
# trip number: 28
# timestamp: 2023-10-12 16:39:53
# trip id: 12845656
# first stop sequence: 1
#
# trip number: 29
# timestamp: 2023-10-12 16:58:25
# trip id: 12845657
# first stop sequence: 1
#
# trip number: 30
# timestamp: 2023-10-12 17:06:20
# trip id: 12845658
# first stop sequence: 1
#
# trip number: 31
# timestamp: 2023-10-12 17:07:48
# trip id: 12845659
# first stop sequence: 1
#
# trip number: 32
# timestamp: 2023-10-12 17:28:59
# trip id: 12845660
# first stop sequence: 1
#
# trip number: 33
# timestamp: 2023-10-12 17:36:53
# trip id: 12845661
# first stop sequence: 1
#
# trip number: 34
# timestamp: 2023-10-12 17:50:19
# trip id: 12845662
# first stop sequence: 1
#
# trip number: 35
# timestamp: 2023-10-12 17:58:52
# trip id: 12845663
# first stop sequence: 1
#
# trip number: 36
# timestamp: 2023-10-12 18:13:51
# trip id: 12845664
# first stop sequence: 1
#
# trip number: 37
# timestamp: 2023-10-12 18:26:17
# trip id: 12845665
# first stop sequence: 1
#
# trip number: 38
# timestamp: 2023-10-12 18:43:55
# trip id: 12845666
# first stop sequence: 1
#
# trip number: 39
# timestamp: 2023-10-12 18:55:17
# trip id: 12845667
# first stop sequence: 1
#
# trip number: 40
# timestamp: 2023-10-12 19:00:20
# trip id: 12845668
# first stop sequence: 1
#
# trip number: 41
# timestamp: 2023-10-12 19:15:25
# trip id: 12845669
# first stop sequence: 1
#
# trip number: 42
# timestamp: 2023-10-12 19:30:08
# trip id: 12845670
# first stop sequence: 1
#
# trip number: 43
# timestamp: 2023-10-12 19:47:16
# trip id: 12845671
# first stop sequence: 1
#
# trip number: 44
# timestamp: 2023-10-12 19:58:41
# trip id: 12845672
# first stop sequence: 1
#
# trip number: 45
# timestamp: 2023-10-12 20:02:14
# trip id: 12845673
# first stop sequence: 1
#
# trip number: 46
# timestamp: 2023-10-12 20:18:26
# trip id: 12845674
# first stop sequence: 1
#
# trip number: 47
# timestamp: 2023-10-12 20:31:54
# trip id: 12845675
# first stop sequence: 1
#
# trip number: 48
# timestamp: 2023-10-12 20:38:04
# trip id: 12845676
# first stop sequence: 1
#
# trip number: 49
# timestamp: 2023-10-12 21:00:21
# trip id: 12845677
# first stop sequence: 1
#
# trip number: 50
# timestamp: 2023-10-12 21:01:00
# trip id: 12845678
# first stop sequence: 1
#
# trip number: 51
# timestamp: 2023-10-12 21:15:29
# trip id: 12845679
# first stop sequence: 1
#
# trip number: 52
# timestamp: 2023-10-12 21:23:00
# trip id: 12845680
# first stop sequence: 1
#
# trip number: 53
# timestamp: 2023-10-12 21:36:43
# trip id: 12845681
# first stop sequence: 1
#
# trip number: 54
# timestamp: 2023-10-12 21:52:00
# trip id: 12845682
# first stop sequence: 1
#
# trip number: 55
# timestamp: 2023-10-12 22:02:49
# trip id: 12845683
# first stop sequence: 1
#
# trip number: 56
# timestamp: 2023-10-12 22:13:56
# trip id: 12845684
# first stop sequence: 1
#
# trip number: 57
# timestamp: 2023-10-12 22:26:06
# trip id: 12845685
# first stop sequence: 1
#
# trip number: 58
# timestamp: 2023-10-12 22:40:50
# trip id: 12845686
# first stop sequence: 1
#
# trip number: 59
# timestamp: 2023-10-12 22:48:39
# trip id: 12845687
# first stop sequence: 1
#
# trip number: 60
# timestamp: 2023-10-12 22:59:01
# trip id: 12845688
# first stop sequence: 1
#
# trip number: 61
# timestamp: 2023-10-12 23:16:39
# trip id: 12845689
# first stop sequence: 1
#
# trip number: 62
# timestamp: 2023-10-12 23:25:48
# trip id: 12845690
# first stop sequence: 1
#
# trip number: 63
# timestamp: 2023-10-12 23:40:04
# trip id: 12845691
# first stop sequence: 1
#
# trip number: 64
# timestamp: 2023-10-12 23:48:33
# trip id: 12845692
# first stop sequence: 1
#
# trip number: 65
# timestamp: 2023-10-13 00:00:58
# trip id: 12845694
# first stop sequence: 1
#
# trip number: 66
# timestamp: 2023-10-13 00:12:38
# trip id: 12845695
# first stop sequence: 1
#
# trip number: 68
# timestamp: 2023-10-13 00:28:11
# trip id: 12845696
# first stop sequence: 1
#
# trip number: 69
# timestamp: 2023-10-13 00:31:44
# trip id: 12845697
# first stop sequence: 1
#
# trip number: 70
# timestamp: 2023-10-13 00:52:13
# trip id: 12845698
# first stop sequence: 1
#
# trip number: 71
# timestamp: 2023-10-13 00:59:13
# trip id: 12845699
# first stop sequence: 1

# %%
df2
# Out:
#        index    tripId  tripDirectionId    vehicleTimestamp  \
# 0       1191  12845636                0 2023-10-12 12:01:05
# 1       1199  12845636                0 2023-10-12 12:01:35
# 2       1207  12845636                0 2023-10-12 12:02:05
# 3       1215  12845636                0 2023-10-12 12:02:36
# 4       1223  12845636                0 2023-10-12 12:03:06
# ...      ...       ...              ...                 ...
# 10333  10849  12845730                0 2023-10-12 09:29:43
# 10334  10851  12845730                0 2023-10-12 09:30:10
# 10335  10852  12845730                0 2023-10-12 09:30:29
# 10336  10854  12845730                0 2023-10-12 09:30:59
# 10337  10856  12845730                0 2023-10-12 09:31:29
#
#                vehicleLabel  vehicleID  vehicleLat  vehicleLong  \
# 0            FX2 To Gresham       4517   45.527650  -122.675560
# 1            FX2 To Gresham       4517   45.527650  -122.675560
# 2            FX2 To Gresham       4517   45.527650  -122.675560
# 3            FX2 To Gresham       4517   45.527650  -122.675560
# 4            FX2 To Gresham       4517   45.527650  -122.675560
# ...                     ...        ...         ...          ...
# 10333  FX2 To Cleveland Ave       4512   45.502922  -122.427500
# 10334  FX2 To Cleveland Ave       4512   45.502930  -122.426520
# 10335  FX2 To Cleveland Ave       4512   45.502945  -122.426150
# 10336  FX2 To Cleveland Ave       4512   45.503002  -122.422170
# 10337  FX2 To Cleveland Ave       4512   45.503033  -122.419266
#
#        vehicleBearing  vehicleStopSequence  vehicleStopID vehicleCurrentStatus
# 0                 178                    1           9302           STOPPED_AT
# 1                 178                    1           9302           STOPPED_AT
# 2                 178                    1           9302           STOPPED_AT
# 3                 178                    1           9302           STOPPED_AT
# 4                 178                    1           9302           STOPPED_AT
# ...               ...                  ...            ...                  ...
# 10333              89                   41           8199        IN_TRANSIT_TO
# 10334              89                   42          14230        IN_TRANSIT_TO
# 10335              85                   42          14230        IN_TRANSIT_TO
# 10336              88                   42          14230        IN_TRANSIT_TO
# 10337              88                   42          14230        IN_TRANSIT_TO
#
# [10338 rows x 12 columns]

# %%
df2[df2["tripId"]== 12845725]
# Out:
#          tripId  tripDirectionId    vehicleTimestamp          vehicleLabel  \
# 7      12845725                0 2023-10-12 06:59:38        FX2 To Gresham
# 15     12845725                0 2023-10-12 07:00:08        FX2 To Gresham
# 31     12845725                0 2023-10-12 07:00:38        FX2 To Gresham
# 47     12845725                0 2023-10-12 07:01:08        FX2 To Gresham
# 55     12845725                0 2023-10-12 07:01:23        FX2 To Gresham
# ...         ...              ...                 ...                   ...
# 261    12845725                0 2023-10-12 07:57:54  FX2 To Cleveland Ave
# 25757  12845725                0 2023-10-12 07:53:54  FX2 To Cleveland Ave
# 273    12845725                0 2023-10-12 07:58:24  FX2 To Cleveland Ave
# 279    12845725                0 2023-10-12 07:58:33  FX2 To Cleveland Ave
# 309    12845725                0 2023-10-12 07:59:54  FX2 To Cleveland Ave
#
#        vehicleID  vehicleLat  vehicleLong  vehicleBearing  \
# 7           4529   45.527695  -122.675570             178
# 15          4529   45.527695  -122.675570             178
# 31          4529   45.527695  -122.675570             178
# 47          4529   45.527500  -122.675560             178
# 55          4529   45.527450  -122.675550             178
# ...          ...         ...          ...             ...
# 261         4529   45.502926  -122.427000              89
# 25757       4529   45.504414  -122.433370              90
# 273         4529   45.502930  -122.426636              88
# 279         4529   45.502937  -122.426280              85
# 309         4529   45.502937  -122.426280              85
#
#        vehicleStopSequence  vehicleStopID vehicleCurrentStatus
# 7                        1           9302           STOPPED_AT
# 15                       1           9302           STOPPED_AT
# 31                       1           9302           STOPPED_AT
# 47                       2           9301        IN_TRANSIT_TO
# 55                       2           9301        IN_TRANSIT_TO
# ...                    ...            ...                  ...
# 261                     41           8199           STOPPED_AT
# 25757                   41           8199        IN_TRANSIT_TO
# 273                     42          14230        IN_TRANSIT_TO
# 279                     42          14230        IN_TRANSIT_TO
# 309                     42          14230        IN_TRANSIT_TO
#
# [123 rows x 11 columns]

# %%
df.groupby("tripId").head(1).sort_values("vehicleTimestamp")
# Out:
#          tripId  tripDirectionId    vehicleTimestamp          vehicleLabel  \
# 2      12782282                0 2023-10-07 06:59:47        FX2 To Gresham
# 3      12782281                0 2023-10-07 06:59:50        FX2 To Gresham
# 4      12782280                0 2023-10-07 07:00:08  FX2 To Cleveland Ave
# 9      12782283                0 2023-10-07 07:00:23        FX2 To Gresham
# 293    12782284                0 2023-10-07 07:09:14        FX2 To Gresham
# ...         ...              ...                 ...                   ...
# 55314  12782099                0 2023-10-08 05:30:38        FX2 To Gresham
# 55853  12782100                0 2023-10-08 05:46:43        FX2 To Gresham
# 54476  12782101                0 2023-10-08 06:15:33        FX2 To Gresham
# 54990  12782102                0 2023-10-08 06:34:35        FX2 To Gresham
# 55922  12782103                0 2023-10-08 06:48:15        FX2 To Gresham
#
#        vehicleID  vehicleLat  vehicleLong  vehicleBearing  \
# 2           4523   45.504803  -122.638750              90
# 3           4524   45.504456  -122.566765              91
# 4           4526   45.502960  -122.428030             105
# 9           4522   45.527534  -122.675560             178
# 293         3709   45.527695  -122.675570             178
# ...          ...         ...          ...             ...
# 55314       4517   45.527695  -122.675570             178
# 55853       4511   45.527695  -122.675570             178
# 54476       4523   45.527695  -122.675570             178
# 54990       4526   45.527695  -122.675570             178
# 55922       4501   45.527695  -122.675570             178
#
#        vehicleStopSequence  vehicleStopID vehicleCurrentStatus
# 2                       13         1447.0        IN_TRANSIT_TO
# 3                       24         1359.0        IN_TRANSIT_TO
# 4                       41         8199.0        IN_TRANSIT_TO
# 9                        2         9301.0        IN_TRANSIT_TO
# 293                      1         9302.0           STOPPED_AT
# ...                    ...            ...                  ...
# 55314                    1         9302.0           STOPPED_AT
# 55853                    1         9302.0           STOPPED_AT
# 54476                    1         9302.0           STOPPED_AT
# 54990                    1         9302.0           STOPPED_AT
# 55922                    1         9302.0           STOPPED_AT
#
# [95 rows x 11 columns]

# %%
df2.groupby("tripId").head(1)["vehicleStopSequence"].unique()
# Out:
# array([ 1,  2, 31, 10])
